# %% [markdown]
# ### In the following code we want to trigger the exception if we are not passwd Bob Jones

# %%
class Person:
    def __init__(self, name=None):
        self._name=name  # Note that we're calling the _attribute, not the @property

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self,value):
        if not (value in ('Bob Jones')):
            raise Exception ("Invalid Bob")
        self._name = value

# %%
bob = Person("Bob Smith")

# %%
bob.name
# Out:
# 'Bob Smith'

# %% [markdown]
# ### Uh oh... Bob Smith is an invalid Bob... what went wrong?  Let's try again....

# %%
class Person:
    def __init__(self, name=None):
        self.name = name  # Note that I'm calling the @property, not the _attribute.

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self,value):
        if not (value in ('Bob Jones')):
            raise Exception ("Invalid Bob")
        self._name = value

# %%
bob = Person("Bob Smith")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-2bc01f1e0eef> in <module>()
# ----> 1 bob = Person("Bob Smith")
#
# <ipython-input-4-4a4a91c048e7> in __init__(self, name)
#       1 class Person:
#       2     def __init__(self, name=None):
# ----> 3         self.name = name
#       4
#       5     @property
#
# <ipython-input-4-4a4a91c048e7> in name(self, value)
#      10     def name(self,value):
#      11         if not (value in ('Bob Jones')):
# ---> 12             raise Exception ("Invalid Bob")
#      13         self._name = value
#
# Exception: Invalid Bob

# %% [markdown]
# ### See the difference?  Look at the declaration of name vs _name in the __init__
